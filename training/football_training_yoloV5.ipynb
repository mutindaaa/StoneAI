# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NoY5aFNQBNbMeGSNDzNM")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(2)
dataset = version.download("yolov5")

# %%
dataset.location

# %%
import shutil
shutil.move('football-players-detection-2/train', 'football-players-detection-2/football-players-detection-2/train')
shutil.move('football-players-detection-2/test', 'football-players-detection-2/football-players-detection-2/test')
shutil.move('football-players-detection-2/valid', 'football-players-detection-2/football-players-detection-2/valid')

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
